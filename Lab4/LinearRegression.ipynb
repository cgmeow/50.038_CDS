# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
from statistics import variance
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np


dataset = np.loadtxt("data.csv", delimiter=",")
X = dataset[:,0]
Y = dataset[:,1]
df = pd.DataFrame(dataset)

df.describe()
mean_X = df[0].mean()
mean_Y = df[1].mean()
xy= zip(X,Y)
covariance =0
variance=0
for xi,yi in xy:
    covariance += xi*yi -mean_Y*xi
    variance += xi*xi - mean_X*xi
B = covariance/variance
a = mean_Y -(B*mean_X)
# a = mean_Y - (B*mean_X)
print(B)
print(a)

Y_pred = B*X + a
plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()
# Out:
# 1.322431022755384
# 7.991020982269163

# %%
#Y=mX+c
m = 0
c = 0
L = 0.0001  #Learning rate
epochs = 10000

n = float(len(X)) # Number of elements in X
# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X+c  # The current predicted value of Y
    D_m = (-2/n)*sum(X*(Y-Y_pred))  # Derivative wrt m
    D_c = (-2/n)*sum(Y-Y_pred)  # Derivative wrt c
    m = m-L*D_m  # Update m
    c = c-L*D_c  # Update c
    
print (m, c)
Y_pred = m*X + c
plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()
# Out:
# 1.4675440436333027 0.6078985997054932

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer


df = pd.read_csv("chicago_hotel_reviews.csv")
X = df.iloc[:,2]
Y = df.iloc[:,3]
print(X[:10])


# steps = [('scaler', StandardScaler()), ('SVM', SVC())]
# pipeline = Pipeline(steps) # define the pipeline object.
# X_train, X_test, y_train, y_test = train_test_split(input_x,input_y,test_size=0.2) #split train test
# pipeline.fit(x_train, y_train) #fit
# predicted = pipeline.predict(x_test) #predict regressor
# print(mean_squared_error(y_test, predicted)) #calculate mean square error
# Out:
# 0    \tWonderful\tI had a sore throat and the hotel...
# 1    Nov 20 2009 \tDidn't want to check out...\tPer...
# 2    \tWOW!!\tGreat hotel! Stayed there with my wif...
# 3    \tStaff Went Above \tWhile waiting for our gue...
# 4    \tWonderful Hotel Will Definately Stay Here Ag...
# 5    \tPerfection\tOur family of 3 stayed for 4 nig...
# 6    Nov 19 2009 \tGREAT FIVE STAR\tI have become a...
# 7    \tDefinite Return Trip to this One!\tThis was ...
# 8    \tGreat hotel!\tThe staff was amazing.The brea...
# 9    \tPerfection in service.\tWe recently travelle...
# Name: review, dtype: object
